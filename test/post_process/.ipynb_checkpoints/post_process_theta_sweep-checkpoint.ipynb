# %%
import pandas as pd
df = pd.read_csv("../theta_sweep.csv")
display(df)
# Out:
#       THETA_PS HW_SAMPLES PULSE_POS
# 0           10         64      RISE
# 1           10          0  SAT_RISE
# 2           20          0      FALL
# 3           20         64  SAT_FALL
# 4           30         64      RISE
# ...        ...        ...       ...
# 9995     49980         64  SAT_FALL
# 9996     49990          0      RISE
# 9997     49990          0  SAT_RISE
# 9998     50000         36      FALL
# 9999     50000         64  SAT_FALL
#
# [10000 rows x 3 columns]

# %%
df_rise = df[df["PULSE_POS"]=="RISE"]
df_rise.plot(x="THETA_PS", y="HW_SAMPLES", marker = 'o', title='Rising Transition w/ Tclk=20ns')
df_fall = df[df["PULSE_POS"]=="FALL"]
df_fall.plot(x="THETA_PS", y="HW_SAMPLES", marker = 'o', title='Falling Transition  w/ Tclk=20ns')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 df_rise = df[df["PULSE_POS"]=="RISE"]
# ----> 2 df_rise.plot(x="THETA_PS", y="HW_SAMPLES", marker = 'o', title='Rising Transition w/ Tclk=20ns')
#       3 df_fall = df[df["PULSE_POS"]=="FALL"]
#       4 df_fall.plot(x="THETA_PS", y="HW_SAMPLES", marker = 'o', title='Falling Transition  w/ Tclk=20ns')
#
# File /opt/tt/venv/lib/python3.10/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /opt/tt/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /opt/tt/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File /opt/tt/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
df_fall = df[(df["PULSE_POS"]=="FALL") & (df["HW_SAMPLES"] != "x")]
df_fall["THETA_PS"] = pd.to_numeric(df_fall["THETA_PS"])
df_fall["HW_SAMPLES"] = pd.to_numeric(df_fall["HW_SAMPLES"])
df_fall.plot(x="THETA_PS", y="HW_SAMPLES", marker = 'o', title='Falling Transition  w/ Tclk=20ns')
df_rise = df[(df["PULSE_POS"]=="RISE") & (df["HW_SAMPLES"]!= "x")]
df_rise["THETA_PS"] = pd.to_numeric(df_rise["THETA_PS"])
df_rise["HW_SAMPLES"] = pd.to_numeric(df_rise["HW_SAMPLES"])
df_rise.plot(x="THETA_PS", y="HW_SAMPLES", marker = 'o', title='Rising Transition  w/ Tclk=20ns')
# Out:
# /tmp/ipykernel_1658741/3545932196.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fall["THETA_PS"] = pd.to_numeric(df_fall["THETA_PS"])
# /tmp/ipykernel_1658741/3545932196.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fall["HW_SAMPLES"] = pd.to_numeric(df_fall["HW_SAMPLES"])
# /tmp/ipykernel_1658741/3545932196.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rise["THETA_PS"] = pd.to_numeric(df_rise["THETA_PS"])
# /tmp/ipykernel_1658741/3545932196.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rise["HW_SAMPLES"] = pd.to_numeric(df_rise["HW_SAMPLES"])
# <Axes: title={'center': 'Falling Transition  w/ Tclk=20ns'}, xlabel='THETA_PS'>
